# %% [markdown]
# <a href="https://colab.research.google.com/github/praffuln/langchain/blob/master/langchain-2/langchain_9_googleDrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain==0.0.284
# !pip install python-dotenv==1.0.0
# !pip install streamlit==1.22.0
# !pip install tiktoken==0.4.0
# !pip install faiss-cpu==1.7.4
# !pip install protobuf~=3.19.0
# !pip install google-generativeai
# !pip install InstructorEmbedding
# !pip install sentence_transformers
# !pip install chromadb
# !pip install google-api-python-client
# !pip install google-auth-httplib2
# !pip install google-auth-oauthlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 16.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 51.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 26.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 81.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.4 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import os
os.environ['HUGGINGFACEHUB_API_TOKEN'] = ""

# %%
from langchain.document_loaders import GoogleDriveLoader
import os

# %%
loader = GoogleDriveLoader(document_ids=["1NiSc6L63Xw3FpkvtXu8aO6I1fg1pBk4r"],
                           credentials_path= '/content/sample_data/credentials.json',
                           recursive=False)
docs = loader.load()
docs
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=450215112241-4pmdt0kkjvk8fu5b0h6ei9dk92plm7ue.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A38565%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.readonly&state=jmHe3HkuVkDzkQF3WZFZg5RrKpCpMR&access_type=offline
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-3e686f884526> in <cell line: 5>()
#       3
#       4                            recursive=False)
# ----> 5 docs = loader.load()
#       6 docs
#
# /usr/local/lib/python3.10/dist-packages/langchain/document_loaders/googledrive.py in load(self)
#     353             )
#     354         elif self.document_ids:
# --> 355             return self._load_documents_from_ids()
#     356         else:
#     357             return self._load_file_from_ids()
#
# ...
