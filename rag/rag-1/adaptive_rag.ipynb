# %% [markdown]
# <a href="https://colab.research.google.com/github/praffuln/generative-ai/blob/master/rag/rag-1/adaptive_rag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('adaptive-rag')

# %% [markdown]
# # Adaptive RAG
#
# Adaptive RAG is a strategy for RAG that unites (1) query analysis with (2) active / self-corrective RAG.
#
# In the paper, they report query analysis to route across:
#
#         No Retrieval
#         Single-shot RAG
#         Iterative RAG
#         Let's build on this using LangGraph.
#
#
#
# In our implementation, we will route between:
#
#       Web search: for questions related to recent events
#
#       Self-corrective RAG: for questions related to our index
#
#
#
# ![image.png](data:image/png;base64,...)
